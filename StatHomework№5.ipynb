# %% [markdown]
# # **Домашняя работа к уроку 5. Тестирование гипотез**
#
# ---

# %% [markdown]
# **1) Когда используется критерий Стьюдента, а когда Z –критерий?**
#
# Задачи 2,3 решать вручную
#
# 2) Проведите тест гипотезы.
#
# **Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.**
#
# 3) Проведите тест гипотезы.
#
# **Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%? (Провести двусторонний тест.)**
#
# Задачу 4 решать с помощью функции.
#
# **4) Есть ли статистически значимые различия в росте дочерей? Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169, 165 Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160**

# %% [markdown]
# **1) Когда используется критерий Стьюдента, а когда Z –критерий?**

# %% [markdown]
# Z-критерий используется, когда:
#
# *   Размер выборки достаточно большой (обычно $𝑛 > 30$).
# *   Известна дисперсия генеральной совокупности.
# *   Выборка следует нормальному распределению.
#
# Критерий Стьюдента (t-критерий) используется, когда:
#
# *   Размер выборки небольшой (обычно $𝑛 ≤ 30$).
# *   Дисперсия генеральной совокупности неизвестна.
# *   Выборка следует нормальному распределению или почти нормальному.

# %% [markdown]
# **2) Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм. Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.**
#
# ***Условие задачи:***
#
# $𝑛 = 100$ (размер выборки)
#
# Средний диаметр шариков $\bar{x} = 17.5мм$
#
# Заявленное среднее значение ${μ_0} = 17мм$
#
# Дисперсия $𝜎^2 = 4 кв.мм$ (стандартное отклонение $𝜎 = 2 мм$)
#
# Уровень значимости $α = 0.05$
#
# ***Формулировка гипотез:***
#
# $H_0 : μ = 17$ (нулевая гипотеза)
#
# $H_1 : μ > 17$ (альтернативная гипотеза)
#
# ***Вычисление Z-статистики:***
#
# $Z = \frac{\bar{x} - \mu_0}{\sigma / \sqrt{n}}$
#
# $Z = \frac{17.5 - 17}{2 / \sqrt{100}} = \frac{0.5}{0.2} = 2.5$
#
# ***Определение критического значения:***
#
# Для одностороннего теста с $α = 0.05$, критическое значение $Z_α = 1.645$
#
# ***Принятие решения и вывод:***
#
# Поскольку
# $𝑍 = 2.5 > 1.645$, отвергаем нулевую гипотезу.
#
# Утверждение о том, что средний диаметр шариков равен 17 мм, не подтверждается.

# %% [markdown]
# **3)Продавец утверждает, что средний вес пачки печенья составляет 200 г. Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет: 202, 203, 199, 197, 195, 201, 200, 204, 194, 190. Известно, что их веса распределены нормально. Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%? (Провести двусторонний тест.)**

# %% [markdown]
# ***Условие задачи:***
#
# $n = 10$ (размер выборки)
#
# Вес пачек: $202, 203, 199, 197, 195, 201, 200, 204, 194, 190$
#
# Заявленное среднее значение: $μ = 200 г$
#
# Уровень значимости $𝛼 = 0.01$ (доверительная вероятность 99%)
#
# ***Формулировка гипотез:***
#
# $H_0 : μ = 200$ (нулевая гипотеза)
#
# $H_1 : μ \neq 200$ (альтернативная гипотеза)
#
# ***Вычисление среднего и стандартного отклонения:***
#
# $\bar{X} = \frac{202+203+199+197+195+201+200+204+194+190}{10} = 198.5$
#
# $s = \sqrt{\frac{∑(X_i - \bar{X})^2}{n-1}}$
#
# Вычисление $𝑠$ дает примерно $5.16$
#
# ***Вычисление t-статистики:***
#
# $t = \frac{\bar{X} - μ}{s / \sqrt{n}}$
#
# $t = \frac{198.5 - 200}{5.16 / \sqrt{10}} \approx -0.96$
#
# ***Определение критического значения:***
#
# Для двустороннего теста с $α = 0.01$ и $df = 9$, критические значения $t_{α/2,df} = \pm3.25$
#
# ***Принятие решения:***
#
# Поскольку $∣t∣ = 0.96 < 3.25$, мы не отвергаем нулевую гипотезу
#
# **Вывод:** Утверждение продавца о том, что средний вес пачки печенья составляет 200 г, подтверждается.

# %% [markdown]
# **4) Есть ли статистически значимые различия в росте дочерей? Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169, 165 Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160**

# %%
import numpy as np
from scipy import stats

# Рост матерей
mothers_height = np.array([172, 177, 158, 170, 178, 175, 164, 160, 169])

# Рост дочерей
daughters_height = np.array([173, 175, 162, 174, 175, 168, 155, 170, 160])

# Проверка на одинаковую длину массивов
if len(mothers_height) != len(daughters_height):
    print("Ошибка: массивы роста матерей и дочерей должны быть одинаковой длины.")
else:
    # Вычисление парного t-теста
    t_stat, p_value = stats.ttest_rel(mothers_height, daughters_height)

    # Вывод результатов
    print(f"t-статистика: {t_stat}")
    print(f"p-значение: {p_value}")

    # Определение статистической значимости
    alpha = 0.05
    if p_value < alpha:
        print("Отвергаем нулевую гипотезу: есть статистически значимые различия в росте дочерей.")
    else:
        print("Не отвергаем нулевую гипотезу: нет статистически значимых различий в росте дочерей.")
# Out:
# t-статистика: 0.559522990335608
# p-значение: 0.5911212354055175
# Не отвергаем нулевую гипотезу: нет статистически значимых различий в росте дочерей.

# %% [markdown]
# Убрал одно ззначение в росте матерей
